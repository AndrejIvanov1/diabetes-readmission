# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_dir = 'data'
df_train = pd.read_csv(os.path.join(data_dir, 'diab_train.csv'), index_col=0)
df_train
# Out:
#                  race  gender      age weight admission_type_id  \
# 9011  AfricanAmerican    Male  [60-70)      ?         Emergency
# 9569        Caucasian  Female  [70-80)      ?          Elective
# 6090        Caucasian  Female  [80-90)      ?            Urgent
# 4282  AfricanAmerican  Female  [50-60)      ?         Emergency
# 9084        Caucasian    Male  [80-90)      ?          Elective
# ...               ...     ...      ...    ...               ...
# 5164        Caucasian  Female  [50-60)      ?         Emergency
# 8645  AfricanAmerican  Female  [70-80)      ?         Emergency
# 5464        Caucasian  Female  [50-60)      ?         Emergency
# 746   AfricanAmerican    Male  [50-60)      ?         Emergency
# 1625        Caucasian  Female  [60-70)      ?         Emergency
#
#                                discharge_disposition_id admission_source_id  \
# 9011                                 Discharged to home      Emergency Room
# ...

# %%
# RACE COLUMN
df_train['race'].value_counts()
# Out:
# Caucasian          4418
# AfricanAmerican    1237
# ?                   124
# Hispanic            116
# Other                74
# Asian                31
# Name: race, dtype: int64

# %%
df_train['gender'].value_counts()
# Out:
# Female    3227
# Male      2773
# Name: gender, dtype: int64

# %%
df_train['age'].value_counts()
# Out:
# [70-80)     1550
# [60-70)     1330
# [50-60)     1024
# [80-90)      976
# [40-50)      563
# [30-40)      250
# [90-100)     153
# [20-30)       79
# [10-20)       57
# [0-10)        18
# Name: age, dtype: int64

# %%
df_train['weight'].value_counts()
# Out:
# ?            5757
# [75-100)      100
# [50-75)        76
# [100-125)      42
# [125-150)      10
# [25-50)         8
# [150-175)       4
# [0-25)          3
# Name: weight, dtype: int64

# %%
df_train['admission_source_id'].value_counts()
# Out:
# Emergency Room                                    3016
# Physician Referral                                1777
# Transfer from a hospital                           234
# Transfer from another health care facility         200
# Clinic Referral                                    111
# Transfer from a Skilled Nursing Facility (SNF)      79
# HMO Referral                                        18
# Not Available                                        7
# Not Mapped                                           7
# Name: admission_source_id, dtype: int64

# %%
df_train['glipizide.metformin'].value_counts()
# Out:
# No    6000
# Name: glipizide.metformin, dtype: int64

# %%
df_train['diag_3_desc'].value_counts()
# Out:
# Diabetes mellitus without mention of complication, type II or unspecified type, not stated as uncontrolled    737
# Malignant essential hypertension                                                                              562
# Hyperosmolality and/or hypernatremia                                                                          274
# Congestive heart failure, unspecified                                                                         253
# Paroxysmal supraventricular tachycardia                                                                       237
#                                                                                                              ...
# Solitary cyst of breast                                                                                         1
# Carbuncle and furuncle of face                                                                                  1
# ...

# %%
df_train.columns
# Out:
# Index(['race', 'gender', 'age', 'weight', 'admission_type_id',
#        'discharge_disposition_id', 'admission_source_id', 'time_in_hospital',
#        'payer_code', 'medical_specialty', 'num_lab_procedures',
#        'num_procedures', 'num_medications', 'number_outpatient',
#        'number_emergency', 'number_inpatient', 'diag_1', 'diag_2', 'diag_3',
#        'number_diagnoses', 'max_glu_serum', 'A1Cresult', 'metformin',
#        'repaglinide', 'nateglinide', 'chlorpropamide', 'glimepiride',
#        'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
#        'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
#        'tolazamide', 'examide', 'citoglipton', 'insulin',
#        'glyburide.metformin', 'glipizide.metformin',
#        'glimepiride.pioglitazone', 'metformin.rosiglitazone',
#        'metformin.pioglitazone', 'change', 'diabetesMed', 'readmitted',
#        'diag_1_desc', 'diag_2_desc', 'diag_3_desc'],
#       dtype='object')
